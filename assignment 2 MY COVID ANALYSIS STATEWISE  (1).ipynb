# %%
LIST_1_NAME_OF_STATES=['Andhra Pradesh',
'Arunachal Pradesh',
'Assam',
'Bihar',
'Chandigarh',
'Chhattisgarh',
'Dadra and Nagar Haveli',
'Delhi',
'Goa',
'Gujarat',
'Haryana',
'Himachal Pradesh',
'Jammu and Kashmir',
'Jharkhand',
'Karnataka',
'Kerala',
'Ladakh',
'Madhya Pradesh',
'Maharashtra',
'Meghalaya',
'Odisha',
'Puducherry',
'Punjab',
'Rajasthan',
'Tamil Nadu',
'Telengana',
'Tripura',
'Uttar Pradesh',
'Uttarakhand',
'West Bengal']

# %%
LIST_2_NUMBER_OF_INFECTED=[38044
,543
,19754
,21764
,651
,4732
,552
,118645
,3108
,45481
,24002
,1377
,12156
,4624
,51422
,10275
,1147
,20378
,284281
,377
,15392
,1743
,9094
,27174
,156369
,41018
,2283
,43441
,3982
,36117
]

# %%
LIST_3_RECOVERED=[19393
,153
,12888
,14018
,476
,3451
,371
,97693
,1817
,32103
,18185
,984
,6446
,2513
,19729
,4862
,970
,14127
,158140
,66
,10877
,947
,6277
,19970
,107416
,27295
,1604
,26675
,2995
,21415
]

# %%
LIST_4_DEATHS=[492
,3
,48
,197
,11
,21
,2
,3545
,19
,2089
,322
,11
,222
,42
,1032
,37
,1
,689
,11194
,2
,79
,22
,230
,538
,2236
,396
,3
,1046
,50
,1023
]

# %%
LIST_5_TOTAL_POPULATION=[49577103
,1383727
,31205576
,104099452
,1055450
,25545198
,585764
,16787941
,1458545
,60439692
,25351462
,6864602
,12267032
,32988134
,61095297
,33406061
,274000
,72626809
,112374333
,2966889
,41974219
,1247953
,27743338
,68548437
,72147030
,35003674
,3673917
,199812341
,10086292
,91276115
]

# %%
LIST_7_Active_CASES=[
18159
,387
,6818
,7549
,164
,1260
,179
,17407
,1272
,11289
,5495
,382
,5488
,2069
,30661
,5376
,176
,5562
,114947
,309
,4436
,774
,2587
,6666
,46717
,13327
,676
,15720
,937
,13679]

# %%
print("(Name_of_States, Numbers_in_Recovered)")
for i in range(len(LIST_1_NAME_OF_STATES)):
    LIST_6_Recovered=[(LIST_1_NAME_OF_STATES[i],LIST_3_RECOVERED[i])]
    for i in LIST_6_Recovered:
        print(i)
# Out:
# (Name_of_States, Numbers_in_Recovered)
# ('Andhra Pradesh', 19393)
# ('Arunachal Pradesh', 153)
# ('Assam', 12888)
# ('Bihar', 14018)
# ('Chandigarh', 476)
# ('Chhattisgarh', 3451)
# ('Dadra and Nagar Haveli', 371)
# ('Delhi', 97693)
# ('Goa', 1817)
# ('Gujarat', 32103)
# ('Haryana', 18185)
# ('Himachal Pradesh', 984)
# ('Jammu and Kashmir', 6446)
# ('Jharkhand', 2513)
# ('Karnataka', 19729)
# ('Kerala', 4862)
# ('Ladakh', 970)
# ('Madhya Pradesh', 14127)
# ('Maharashtra', 158140)
# ('Meghalaya', 66)
# ('Odisha', 10877)
# ('Puducherry', 947)
# ('Punjab', 6277)
# ('Rajasthan', 19970)
# ('Tamil Nadu', 107416)
# ('Telengana', 27295)
# ('Tripura', 1604)
# ('Uttar Pradesh', 26675)
# ('Uttarakhand', 2995)
# ('West Bengal', 21415)

# %%
print("(NAME_OF_STATES,NUMBER_OF_INFECTED)")
for i in range(len(LIST_1_NAME_OF_STATES)):
    print('{} has {} infected persons'.format(LIST_1_NAME_OF_STATES[i],LIST_2_NUMBER_OF_INFECTED[i]))
# Out:
# (NAME_OF_STATES,NUMBER_OF_INFECTED)
# Andhra Pradesh has 38044 infected persons
# Arunachal Pradesh has 543 infected persons
# Assam has 19754 infected persons
# Bihar has 21764 infected persons
# Chandigarh has 651 infected persons
# Chhattisgarh has 4732 infected persons
# Dadra and Nagar Haveli has 552 infected persons
# Delhi has 118645 infected persons
# Goa has 3108 infected persons
# Gujarat has 45481 infected persons
# Haryana has 24002 infected persons
# Himachal Pradesh has 1377 infected persons
# Jammu and Kashmir has 12156 infected persons
# Jharkhand has 4624 infected persons
# Karnataka has 51422 infected persons
# Kerala has 10275 infected persons
# Ladakh has 1147 infected persons
# Madhya Pradesh has 20378 infected persons
# Maharashtra has 284281 infected persons
# Meghalaya has 377 infected persons
# Odisha has 15392 infected persons
# Puducherry has 1743 infected persons
# Punjab has 9094 infected persons
# Rajasthan has 27174 infected persons
# ...

# %%
print("Dictionary of Name of States and Number of Infected")
for i in range(len(LIST_1_NAME_OF_STATES)): 
    STATE_INFECTED_DICTIONARY = {LIST_1_NAME_OF_STATES[i]:LIST_2_NUMBER_OF_INFECTED[i]}
    for x,y in STATE_INFECTED_DICTIONARY.items():
        print(x,y)
# Out:
# Dictionary of Name of States and Number of Infected
# Andhra Pradesh 38044
# Arunachal Pradesh 543
# Assam 19754
# Bihar 21764
# Chandigarh 651
# Chhattisgarh 4732
# Dadra and Nagar Haveli 552
# Delhi 118645
# Goa 3108
# Gujarat 45481
# Haryana 24002
# Himachal Pradesh 1377
# Jammu and Kashmir 12156
# Jharkhand 4624
# Karnataka 51422
# Kerala 10275
# Ladakh 1147
# Madhya Pradesh 20378
# Maharashtra 284281
# Meghalaya 377
# Odisha 15392
# Puducherry 1743
# Punjab 9094
# Rajasthan 27174
# Tamil Nadu 156369
# Telengana 41018
# Tripura 2283
# Uttar Pradesh 43441
# Uttarakhand 3982
# West Bengal 36117

# %%
def ifr(infected,deaths):
    ifr=(deaths/infected)
    print("The IFR ={}%".format(ifr))

# %%
for i in range (len(LIST_1_NAME_OF_STATES)):
    print(LIST_1_NAME_OF_STATES[i])
    ifr(LIST_2_NUMBER_OF_INFECTED[i],LIST_4_DEATHS[i])
# Out:
# Andhra Pradesh
# The IFR =0.012932394070024182%
# Arunachal Pradesh
# The IFR =0.0055248618784530384%
# Assam
# The IFR =0.0024298876176976816%
# Bihar
# The IFR =0.009051644918213564%
# Chandigarh
# The IFR =0.016897081413210446%
# Chhattisgarh
# The IFR =0.004437869822485207%
# Dadra and Nagar Haveli
# The IFR =0.0036231884057971015%
# Delhi
# The IFR =0.02987905095031396%
# Goa
# The IFR =0.006113256113256113%
# Gujarat
# The IFR =0.045931268002022824%
# Haryana
# The IFR =0.013415548704274643%
# Himachal Pradesh
# The IFR =0.007988380537400145%
# Jammu and Kashmir
# The IFR =0.01826258637709773%
# Jharkhand
# The IFR =0.009083044982698962%
# Karnataka
# The IFR =0.0200692310684143%
# Kerala
# The IFR =0.0036009732360097325%
# Ladakh
# The IFR =0.0008718395815170009%
# Madhya Pradesh
# The IFR =0.03381097261752871%
# Maharashtra
# The IFR =0.03937653237465747%
# Meghalaya
# The IFR =0.005305039787798408%
# Odisha
# The IFR =0.005132536382536383%
# Puducherry
# ...

# %%
def CMR(DEATHS,TOTAL_POPULATION):
    CMR=(DEATHS/TOTAL_POPULATION)*1000
    print("the crude mortality rate ={}%".format(CMR))

# %%
for i in range (len(LIST_1_NAME_OF_STATES)):
    print(LIST_1_NAME_OF_STATES[i])
    CMR(LIST_4_DEATHS[i],LIST_5_TOTAL_POPULATION[i])
# Out:
# Andhra Pradesh
# the crude mortality rate =0.009923936055723143%
# Arunachal Pradesh
# the crude mortality rate =0.002168057716587159%
# Assam
# the crude mortality rate =0.001538186636901046%
# Bihar
# the crude mortality rate =0.0018924211051562498%
# Chandigarh
# the crude mortality rate =0.010422094841063054%
# Chhattisgarh
# the crude mortality rate =0.0008220723127689204%
# Dadra and Nagar Haveli
# the crude mortality rate =0.0034143443434557262%
# Delhi
# the crude mortality rate =0.21116347740321462%
# Goa
# the crude mortality rate =0.0130266806989157%
# Gujarat
# the crude mortality rate =0.034563379310404166%
# Haryana
# the crude mortality rate =0.01270143710055065%
# Himachal Pradesh
# the crude mortality rate =0.0016024235636676388%
# Jammu and Kashmir
# the crude mortality rate =0.018097287102536296%
# Jharkhand
# the crude mortality rate =0.0012731850792166662%
# Karnataka
# the crude mortality rate =0.016891643885453243%
# Kerala
# ...

# %%
List_infected_persons=[sum(i) for i in zip(LIST_3_RECOVERED,LIST_4_DEATHS,LIST_7_Active_CASES)]
print('Data of infected persons:',format(List_infected_persons))
# Out:
# Data of infected persons: [38044, 543, 19754, 21764, 651, 4732, 552, 118645, 3108, 45481, 24002, 1377, 12156, 4624, 51422, 10275, 1147, 20378, 284281, 377, 15392, 1743, 9094, 27174, 156369, 41018, 2283, 43441, 3982, 36117]
